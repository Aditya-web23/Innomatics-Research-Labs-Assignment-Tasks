# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya-web23/Innomatics-Research-Labs-Assignment-Tasks/blob/main/Task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problem 1: Mobile Recharge Validation System
def validate_recharge(amount):
    valid_plans = [199, 299, 399, 599]

    if amount < 50:
        print("Recharge amount must be at least ₹50")
        return False
    elif amount not in valid_plans:
        print("Invalid plan selected")
        return False
    else:
        print("Recharge Successful!")
        return True


while True:
    amt = int(input("Enter recharge amount: "))
    if validate_recharge(amt):
        break
# Out:
# Enter recharge amount: 399
# Recharge Successful!

# %%
#Problem 2: Inventory Reorder Alert System
def check_inventory(products):
    for product, stock in products.items():
        if stock < 15:
            print(product, "Reorder Alert!!")
        else:
            print(product, "Stock OK")


inventory = {
    "Rice": 20,
    "Sugar": 10,
    "Oil": 5,
    "Salt": 30
}

check_inventory(inventory)
# Out:
# Rice Stock OK
# Sugar Reorder Alert!!
# Oil Reorder Alert!!
# Salt Stock OK

# %%
#Problem 3: Student Result Processing System
def process_result(marks):
    total = 0

    for mark in marks:
        total += mark

    average = total / len(marks)

    if average >= 50:
        return "Pass"
    else:
        return "Fail"


student_marks = [60, 70, 45, 80]
result = process_result(student_marks)

print("Result:", result)
# Out:
# Result: Pass

# %%
#Problem 4: Cab Fare Estimator with Retry Option
def calculate_fare(distance, peak):
    fare = 50 + (12 * distance)

    if peak == "yes":
        fare = fare + (0.25 * fare)

    return fare


while True:
    km = float(input("Enter distance in km: "))
    peak_time = input("Is it peak hour? (yes/no): ")

    total_fare = calculate_fare(km, peak_time)
    print("Total Fare: ₹", total_fare)

    retry = input("Do you want to calculate again? (yes/no): ")
    if retry != "yes":
        break
# Out:
# Enter distance in km: 45
# Is it peak hour? (yes/no): no
# Total Fare: ₹ 590.0
# Do you want to calculate again? (yes/no): no

# %%
#Problem 5: Employee Attendance Eligibility Checker
def check_eligibility(attendance):
    present_days = 0

    for day in attendance:
        if day == "P":
            present_days += 1

    percentage = (present_days / len(attendance)) * 100

    if percentage >= 75:
        return "Eligible"
    else:
        return "Not Eligible"


attendance_list = ["P", "P", "A", "P", "P", "A", "P"]
status = check_eligibility(attendance_list)

print("Attendance Status:", status)
# Out:
# Attendance Status: Not Eligible

# %%
#Problem 6: Password Strength Checker
def check_password(password):
    if len(password) < 8:
        return "Weak Password (Too Short)"

    has_digit = False
    has_special = False

    for ch in password:
        if ch.isdigit():
            has_digit = True
        if ch in "@#$":
            has_special = True

    if has_digit and has_special:
        return "Strong Password"
    else:
        return "Weak Password"


pwd = input("Enter password: ")
print(check_password(pwd))
# Out:
# Enter password: Aditya@23
# Strong Password
