# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya-web23/Innomatics-Research-Labs-Assignment-Tasks/blob/main/Assignment_6_Innomatics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ps1
def parking_system(capacity, logs):
    parked = 0
    max_parked = 0

    for log in logs:
        if log == "IN":
            parked += 1
        elif log == "OUT" and parked > 0:
            parked -= 1

        if parked > max_parked:
            max_parked = parked

    print("Currently Parked Vehicles:", parked)

    if parked > capacity:
        print("Parking Status: Full (Alert!)")
    else:
        print("Parking Status: Available")

parking_system(50, ["IN", "IN", "IN", "OUT", "IN", "IN", "OUT"])
# Out:
# Currently Parked Vehicles: 3
# Parking Status: Available

# %%
#ps2
def delivery_time(distance, traffic, weather):
    time = distance * 5   # base time (5 min per km)

    if traffic == "High":
        time += 15
    elif traffic == "Medium":
        time += 10

    if weather == "Rainy":
        time += 10
    elif weather == "Stormy":
        time += 20

    print("Estimated Delivery Time:", time, "minutes")

# Sample Input
delivery_time(8, "High", "Rainy")
# Out:
# Estimated Delivery Time: 65 minutes

# %%
#ps3
def theatre_occupancy(total_seats, booked_seats):
    booked = len(booked_seats)
    percentage = (booked / total_seats) * 100

    print("Occupancy:", int(percentage), "%")

    if percentage == 100:
        print("Show Status: Housefull")
    elif percentage >= 75:
        print("Show Status: Almost Full")
    else:
        print("Show Status: Available")

# Sample Input (150 bookings)
theatre_occupancy(200, [1]*150)
# Out:
# Occupancy: 75 %
# Show Status: Almost Full

# %%
#ps4
def server_load(cpu_readings):
    avg = sum(cpu_readings) / len(cpu_readings)

    print("Average CPU Load:", int(avg), "%")

    if avg < 50:
        print("Server Status: Normal")
    elif avg <= 80:
        print("Server Status: Warning")
    else:
        print("Server Status: Critical")

# Sample Input
server_load([45, 60, 70, 85, 90])
# Out:
# Average CPU Load: 70 %
# Server Status: Warning

# %%
#ps5
def resource_monitor(resources):
    overused = []

    for resource, hours in resources.items():
        if hours > 8:
            overused.append(resource)

    if overused:
        print("Overused Resources:", ", ".join(overused))
        print("Energy Alert: Yes")
    else:
        print("Overused Resources: None")
        print("Energy Alert: No")

# Sample Input
resource_monitor({
    "Projector": 6,
    "AC": 9,
    "Lights": 4
})
# Out:
# Overused Resources: AC
# Energy Alert: Yes

# %%
#ps6
def event_registration(capacity, registrations):
    if registrations > capacity:
        confirmed = capacity
        waitlist = registrations - capacity
        status = "Closed"
    else:
        confirmed = registrations
        waitlist = 0
        status = "Open"

    print("Confirmed Registrations:", confirmed)
    print("Waitlisted Users:", waitlist)
    print("Registration Status:", status)

# Sample Input
event_registration(100, 105)
# Out:
# Confirmed Registrations: 100
# Waitlisted Users: 5
# Registration Status: Closed
